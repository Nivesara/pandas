# %%
import pandas as pd

# %%
series = pd.Series(["HONDA","NISSAN","AUDI"])

# %%
series
# Out:
# 0     HONDA
# 1    NISSAN
# 2      AUDI
# dtype: object

# %%
colours = pd.Series(["black","orange","white"])

# %%
series
# Out:
# 0     HONDA
# 1    NISSAN
# 2      AUDI
# dtype: object

# %%
colours
# Out:
# 0     black
# 1    orange
# 2     white
# dtype: object

# %%
car_data = pd.DataFrame({"car_model":series, "colour":colours})

# %%
car_data
# Out:
#   car_model  colour
# 0     HONDA   black
# 1    NISSAN  orange
# 2      AUDI   white

# %%
car_sales = pd.read_csv ("7.1 car-sales.csv.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car_sales.csv")

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## 1. describe data

# %%
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_price = pd.Series ([9000,130000,500000])
car_price.mean()
# Out:
# 213000.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head(9)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animals = pd.Series(["tiger","lion","cheeta","monkey","rabbit"], index = [0,3,6,8,9])

# %%
animals
# Out:
# 0     tiger
# 3      lion
# 6    cheeta
# 8    monkey
# 9    rabbit
# dtype: object

# %%
animals.loc[3]
# Out:
# 'lion'

# %%
animals.loc[9]
# Out:
# 'rabbit'

# %%
animals[6]
# Out:
# 'cheeta'

# %%
car_sales.loc[8]
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)        60000
# Doors                    4
# Price            $6,250.00
# Name: 8, dtype: object

# %%
animals.iloc[4]
# Out:
# 'rabbit'

# %%
car_sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
animals.iloc[3]
# Out:
# 'monkey'

# %%
car_sales.iloc[7]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales.iloc[:7]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] >100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales[car_sales["Colour"] =="White"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Colour"]).mean()
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
car_sales["Doors"].plot()

# %%
car_sales["Doors"].hist()

# %%
car_sales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"] = car_sales["Price"].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
car_sales["Price"].plot()

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_missing_data_sales = pd.read_csv("9.1 car-sales-extended-missing-data.csv.csv")

# %%
car_missing_data_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_missing_data_sales["Odometer (KM)"].mean()
# Out:
# 131253.23789473684

# %%
car_missing_data_sales["Odometer (KM)"].fillna(car_missing_data_sales["Odometer (KM)"].mean())
# Out:
# 0       35431.0
# 1      192714.0
# 2       84714.0
# 3      154365.0
# 4      181577.0
#          ...
# 995     35820.0
# 996    155144.0
# 997     66604.0
# 998    215883.0
# 999    248360.0
# Name: Odometer (KM), Length: 1000, dtype: float64

# %%
car_missing_data_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_missing_data_sales["Odometer (KM)"].fillna(car_missing_data_sales["Odometer (KM)"].mean(),inplace=True)

# %%
car_missing_data_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_missing_data_sales.dropna()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
car_missing_data_sales.dropna(inplace=True)

# %%
car_missing_data_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
seats_column = pd.Series([5,5,5,5,5])
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5,inplace= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
fuel_economy = [7.5,8,9,10,8.5,8.8,4.5,8.9,9,5.9]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             8.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 4  nissan  White         213095      4   350000    5.0             8.5
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 6   honda   Blue          45698      4   750000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             5.9

# %%
car_sales["Total fuel used (L)"] = (car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             8.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 4  nissan  White         213095      4   350000    5.0             8.5
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 6   honda   Blue          45698      4   750000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             5.9
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         7031.920             7031.920
# 2         2929.410             2929.410
# ...

# %%
car_sales["Number of wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             8.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 4  nissan  White         213095      4   350000    5.0             8.5
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 6   honda   Blue          45698      4   750000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             5.9
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         7031.920             7031.920                 4
# ...

# %%
car_sales["Passed saftey test"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             8.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 4  nissan  White         213095      4   350000    5.0             8.5
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 6   honda   Blue          45698      4   750000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             5.9
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# 0        11253.225            11253.225                 4                True
# ...

# %%
car_sales.drop("Total fuel used" , axis = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             8.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 4  nissan  White         213095      4   350000    5.0             8.5
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 6   honda   Blue          45698      4   750000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             5.9
#
#    Total fuel used (L)  Number of wheels  Passed saftey test
# 0            11253.225                 4                True
# 1             7031.920                 4                True
# ...

# %%
car_sales["Passed saftey test"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int32
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed saftey test        bool
# dtype: object

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9  nissan  White          31600      4   970000    5.0             5.9
# 8  toyota  White          60000      4   625000    5.0             9.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 3     bmw  Black          11179      5  2200000    5.0            10.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# 9         1864.400             1864.400                 4                True
# 8         5400.000             5400.000                 4                True
# 2         2929.410             2929.410                 4                True
# 7         4871.682             4871.682                 4                True
# 3         1117.900             1117.900                 4                True

# %%
car_sale_suffeled=car_sales.sample(frac=1)

# %%
car_sale_suffeled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0            10.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 7   honda   Blue          54738      4   700000    5.0             8.9
# 5  toyota  Green          99213      4   450000    5.0             8.8
# 1   honda    Red          87899      4   500000    5.0             8.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 4  nissan  White         213095      4   350000    5.0             8.5
# 9  nissan  White          31600      4   970000    5.0             5.9
# 6   honda   Blue          45698      4   750000    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# 2         2929.410             2929.410                 4                True
# ...

# %%
car_sale_suffeled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9  nissan  White          31600      4   970000    5.0             5.9
# 3     bmw  Black          11179      5  2200000    5.0            10.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# 9           1864.4               1864.4                 4                True
# 3           1117.9               1117.9                 4                True

# %%
car_sale_suffeled.sample(frac=0.1)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 4  nissan  White         213095      4  350000    5.0             8.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# 4        18113.075            18113.075                 4                True

# %%
car_sale_suffeled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      2  toyota   Blue          32549      3   700000    5.0             9.0
# 1      3     bmw  Black          11179      5  2200000    5.0            10.0
# 2      8  toyota  White          60000      4   625000    5.0             9.0
# 3      7   honda   Blue          54738      4   700000    5.0             8.9
# 4      5  toyota  Green          99213      4   450000    5.0             8.8
# 5      1   honda    Red          87899      4   500000    5.0             8.0
# 6      0  toyota  White         150043      4   400000    5.0             7.5
# 7      4  nissan  White         213095      4   350000    5.0             8.5
# 8      9  nissan  White          31600      4   970000    5.0             5.9
# 9      6   honda   Blue          45698      4   750000    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# ...

# %%
car_sale_suffeled.reset_index(inplace=True)

# %%
car_sale_suffeled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      2  toyota   Blue          32549      3   700000    5.0             9.0
# 1      3     bmw  Black          11179      5  2200000    5.0            10.0
# 2      8  toyota  White          60000      4   625000    5.0             9.0
# 3      7   honda   Blue          54738      4   700000    5.0             8.9
# 4      5  toyota  Green          99213      4   450000    5.0             8.8
# 5      1   honda    Red          87899      4   500000    5.0             8.0
# 6      0  toyota  White         150043      4   400000    5.0             7.5
# 7      4  nissan  White         213095      4   350000    5.0             8.5
# 8      9  nissan  White          31600      4   970000    5.0             5.9
# 9      6   honda   Blue          45698      4   750000    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# ...

# %%
car_sale_suffeled.reset_index(drop=True , inplace=True)

# %%
car_sale_suffeled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      2  toyota   Blue          32549      3   700000    5.0             9.0
# 1      3     bmw  Black          11179      5  2200000    5.0            10.0
# 2      8  toyota  White          60000      4   625000    5.0             9.0
# 3      7   honda   Blue          54738      4   700000    5.0             8.9
# 4      5  toyota  Green          99213      4   450000    5.0             8.8
# 5      1   honda    Red          87899      4   500000    5.0             8.0
# 6      0  toyota  White         150043      4   400000    5.0             7.5
# 7      4  nissan  White         213095      4   350000    5.0             8.5
# 8      9  nissan  White          31600      4   970000    5.0             5.9
# 9      6   honda   Blue          45698      4   750000    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed saftey test
# ...
